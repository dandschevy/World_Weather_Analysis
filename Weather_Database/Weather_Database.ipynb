# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps
import numpy as np
from datetime import datetime

# Import API key
from config import weather_api_key

# %%
#3  Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
#incorporate citipy
from citipy import citipy

# %%
# 5 Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# 6a Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 760

# %%
# 6b Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list - Enumerate was used since not integers
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_condition = city_weather["weather"][0]["description"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather Condition": weather_condition})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | nanortalik
# Processing Record 2 of Set 1 | arraial do cabo
# Processing Record 3 of Set 1 | college
# Processing Record 4 of Set 1 | norman wells
# Processing Record 5 of Set 1 | ribeira grande
# Processing Record 6 of Set 1 | waingapu
# Processing Record 7 of Set 1 | kodiak
# Processing Record 8 of Set 1 | bonthe
# Processing Record 9 of Set 1 | hobart
# Processing Record 10 of Set 1 | tecoanapa
# Processing Record 11 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 12 of Set 1 | namikupa
# Processing Record 13 of Set 1 | east london
# Processing Record 14 of Set 1 | itoman
# Processing Record 15 of Set 1 | carlagan
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | puerto ayora
# Processing Record 19 of Set 1 | atherton
# Processing Record 20 of Set 1 | qaanaaq
# Processing Record 21 of Set 1 | busselton
# Processing Record 22 of Set 1 | albany
# Processing Record 23 of Set 1 | kapaa
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | chuy
# Processing Record 26 of Set 1 | kahului
# Processing Record 27 of Set 1 | juneau
# Processing Record 28 of Set 1 | aklavik
# Processing Record 29 of Set 1 | ancud
# Processing Record 30 of Set 1 | jutai
# Processing Record 31 of Set 1 | kaeo
# Processing Record 32 of Set 1 | maniitsoq
# Processing Record 33 of Set 1 | codrington
# Processing Record 34 of Set 1 | la ronge
# Processing Record 35 of Set 1 | carutapera
# Processing Record 36 of Set 1 | hermanus
# Processing Record 37 of Set 1 | babanusah
# City not found. Skipping...
# Processing Record 38 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 39 of Set 1 | acapulco
# Processing Record 40 of Set 1 | cacequi
# Processing Record 41 of Set 1 | puerto escondido
# Processing Record 42 of Set 1 | jiaonan
# Processing Record 43 of Set 1 | yellowknife
# Processing Record 44 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 45 of Set 1 | lebu
# Processing Record 46 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 47 of Set 1 | vaini
# Processing Record 48 of Set 1 | carthage
# Processing Record 49 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 1 | bredasdorp
# Processing Record 1 of Set 2 | nikolskoye
# Processing Record 2 of Set 2 | dikson
# Processing Record 3 of Set 2 | naryan-mar
# Processing Record 4 of Set 2 | bluff
# Processing Record 5 of Set 2 | hithadhoo
# Processing Record 6 of Set 2 | egvekinot
# Processing Record 7 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | san jeronimo
# Processing Record 10 of Set 2 | acarau
# Processing Record 11 of Set 2 | avarua
# Processing Record 12 of Set 2 | aljezur
# Processing Record 13 of Set 2 | port elizabeth
# Processing Record 14 of Set 2 | sawtell
# Processing Record 15 of Set 2 | hendijan
# City not found. Skipping...
# Processing Record 16 of Set 2 | lamar
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | punta arenas
# Processing Record 19 of Set 2 | bokovskaya
# Processing Record 20 of Set 2 | taoudenni
# Processing Record 21 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 2 | ngukurr
# City not found. Skipping...
# Processing Record 23 of Set 2 | laguna
# Processing Record 24 of Set 2 | khandbari
# Processing Record 25 of Set 2 | coahuayana
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | mataura
# Processing Record 28 of Set 2 | adrar
# Processing Record 29 of Set 2 | bambous virieux
# Processing Record 30 of Set 2 | znamenka
# Processing Record 31 of Set 2 | mahebourg
# Processing Record 32 of Set 2 | harlingen
# Processing Record 33 of Set 2 | durban
# Processing Record 34 of Set 2 | tiksi
# Processing Record 35 of Set 2 | ponta do sol
# Processing Record 36 of Set 2 | kavieng
# Processing Record 37 of Set 2 | samarai
# Processing Record 38 of Set 2 | ust-kuyga
# Processing Record 39 of Set 2 | lavrentiya
# Processing Record 40 of Set 2 | pisco
# Processing Record 41 of Set 2 | zhob
# Processing Record 42 of Set 2 | castro
# Processing Record 43 of Set 2 | pistsovo
# Processing Record 44 of Set 2 | alofi
# Processing Record 45 of Set 2 | nyurba
# Processing Record 46 of Set 2 | monte patria
# Processing Record 47 of Set 2 | ahipara
# Processing Record 48 of Set 2 | faanui
# Processing Record 49 of Set 2 | warqla
# City not found. Skipping...
# Processing Record 50 of Set 2 | clyde river
# Processing Record 1 of Set 3 | airai
# Processing Record 2 of Set 3 | lompoc
# Processing Record 3 of Set 3 | namibe
# Processing Record 4 of Set 3 | viedma
# Processing Record 5 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 3 | licheng
# Processing Record 7 of Set 3 | esperance
# Processing Record 8 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 9 of Set 3 | tubuala
# Processing Record 10 of Set 3 | sao jose da coroa grande
# Processing Record 11 of Set 3 | ozgon
# City not found. Skipping...
# Processing Record 12 of Set 3 | biak
# Processing Record 13 of Set 3 | diapaga
# Processing Record 14 of Set 3 | bengkulu
# Processing Record 15 of Set 3 | jamestown
# Processing Record 16 of Set 3 | kaitangata
# Processing Record 17 of Set 3 | dunedin
# Processing Record 18 of Set 3 | oyem
# Processing Record 19 of Set 3 | elizabethtown
# Processing Record 20 of Set 3 | seoul
# Processing Record 21 of Set 3 | sirkali
# City not found. Skipping...
# Processing Record 22 of Set 3 | hilo
# Processing Record 23 of Set 3 | victoria
# Processing Record 24 of Set 3 | carnarvon
# Processing Record 25 of Set 3 | coihaique
# Processing Record 26 of Set 3 | halifax
# Processing Record 27 of Set 3 | bulawayo
# Processing Record 28 of Set 3 | bonavista
# Processing Record 29 of Set 3 | saskylakh
# Processing Record 30 of Set 3 | northam
# Processing Record 31 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 32 of Set 3 | tessalit
# Processing Record 33 of Set 3 | merauke
# Processing Record 34 of Set 3 | port hedland
# Processing Record 35 of Set 3 | ierapetra
# Processing Record 36 of Set 3 | constitucion
# Processing Record 37 of Set 3 | ongwediva
# Processing Record 38 of Set 3 | pundaguitan
# Processing Record 39 of Set 3 | fortuna
# Processing Record 40 of Set 3 | katangi
# Processing Record 41 of Set 3 | urubicha
# Processing Record 42 of Set 3 | vangaindrano
# Processing Record 43 of Set 3 | sicamous
# Processing Record 44 of Set 3 | vila do conde
# Processing Record 45 of Set 3 | leningradskiy
# Processing Record 46 of Set 3 | navsari
# Processing Record 47 of Set 3 | vardo
# Processing Record 48 of Set 3 | bilibino
# Processing Record 49 of Set 3 | dibulla
# Processing Record 50 of Set 3 | luwuk
# Processing Record 1 of Set 4 | hirara
# Processing Record 2 of Set 4 | aguimes
# Processing Record 3 of Set 4 | bandarbeyla
# Processing Record 4 of Set 4 | awjilah
# Processing Record 5 of Set 4 | severo-kurilsk
# Processing Record 6 of Set 4 | oranjemund
# Processing Record 7 of Set 4 | wakkanai
# Processing Record 8 of Set 4 | clarence town
# Processing Record 9 of Set 4 | ust-barguzin
# Processing Record 10 of Set 4 | kousseri
# Processing Record 11 of Set 4 | tuktoyaktuk
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | lagoa
# Processing Record 14 of Set 4 | saint-augustin
# Processing Record 15 of Set 4 | klaksvik
# Processing Record 16 of Set 4 | nome
# Processing Record 17 of Set 4 | boa vista
# Processing Record 18 of Set 4 | provideniya
# Processing Record 19 of Set 4 | port hardy
# Processing Record 20 of Set 4 | margate
# Processing Record 21 of Set 4 | kieta
# Processing Record 22 of Set 4 | mar del plata
# Processing Record 23 of Set 4 | chara
# Processing Record 24 of Set 4 | mporokoso
# Processing Record 25 of Set 4 | puerto ayacucho
# Processing Record 26 of Set 4 | itarema
# Processing Record 27 of Set 4 | gra liyia
# Processing Record 28 of Set 4 | tasiilaq
# Processing Record 29 of Set 4 | rawannawi
# City not found. Skipping...
# Processing Record 30 of Set 4 | salalah
# Processing Record 31 of Set 4 | new norfolk
# Processing Record 32 of Set 4 | templemore
# Processing Record 33 of Set 4 | ambunti
# Processing Record 34 of Set 4 | torbay
# Processing Record 35 of Set 4 | palmer
# Processing Record 36 of Set 4 | sofiyivka
# Processing Record 37 of Set 4 | khatanga
# Processing Record 38 of Set 4 | yankton
# Processing Record 39 of Set 4 | carballo
# Processing Record 40 of Set 4 | atuona
# Processing Record 41 of Set 4 | agirish
# Processing Record 42 of Set 4 | eureka
# Processing Record 43 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 44 of Set 4 | bethel
# Processing Record 45 of Set 4 | salinopolis
# Processing Record 46 of Set 4 | buchanan
# Processing Record 47 of Set 4 | touros
# Processing Record 48 of Set 4 | pacific grove
# Processing Record 49 of Set 4 | kiunga
# Processing Record 50 of Set 4 | gusinoye ozero
# Processing Record 1 of Set 5 | bernal
# Processing Record 2 of Set 5 | cockburn town
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | bakhmach
# Processing Record 5 of Set 5 | ambon
# Processing Record 6 of Set 5 | amapa
# Processing Record 7 of Set 5 | mayuge
# Processing Record 8 of Set 5 | nanpiao
# Processing Record 9 of Set 5 | sitka
# Processing Record 10 of Set 5 | san cristobal
# Processing Record 11 of Set 5 | rawson
# Processing Record 12 of Set 5 | deputatskiy
# Processing Record 13 of Set 5 | petauke
# Processing Record 14 of Set 5 | naze
# Processing Record 15 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 16 of Set 5 | asau
# Processing Record 17 of Set 5 | olafsvik
# Processing Record 18 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 19 of Set 5 | longyearbyen
# Processing Record 20 of Set 5 | georgetown
# Processing Record 21 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 22 of Set 5 | tuatapere
# Processing Record 23 of Set 5 | hargeysa
# Processing Record 24 of Set 5 | pitimbu
# Processing Record 25 of Set 5 | paradwip
# City not found. Skipping...
# Processing Record 26 of Set 5 | cabedelo
# Processing Record 27 of Set 5 | skelleftea
# Processing Record 28 of Set 5 | santa cruz
# Processing Record 29 of Set 5 | ginda
# Processing Record 30 of Set 5 | reynosa
# Processing Record 31 of Set 5 | erenhot
# Processing Record 32 of Set 5 | nanakuli
# Processing Record 33 of Set 5 | miandrivazo
# Processing Record 34 of Set 5 | phrai bung
# City not found. Skipping...
# Processing Record 35 of Set 5 | cayenne
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | katsuura
# Processing Record 38 of Set 5 | pevek
# Processing Record 39 of Set 5 | karratha
# Processing Record 40 of Set 5 | sebezh
# Processing Record 41 of Set 5 | altay
# Processing Record 42 of Set 5 | cherskiy
# Processing Record 43 of Set 5 | pincher creek
# Processing Record 44 of Set 5 | ende
# Processing Record 45 of Set 5 | gangotri
# City not found. Skipping...
# Processing Record 46 of Set 5 | okhotsk
# Processing Record 47 of Set 5 | hualmay
# Processing Record 48 of Set 5 | hamilton
# Processing Record 49 of Set 5 | barbar
# City not found. Skipping...
# Processing Record 50 of Set 5 | montepuez
# Processing Record 1 of Set 6 | port alfred
# Processing Record 2 of Set 6 | kangaatsiaq
# Processing Record 3 of Set 6 | bathsheba
# Processing Record 4 of Set 6 | tchaourou
# Processing Record 5 of Set 6 | polis
# Processing Record 6 of Set 6 | banda aceh
# Processing Record 7 of Set 6 | ennis
# Processing Record 8 of Set 6 | aktash
# Processing Record 9 of Set 6 | lakes entrance
# Processing Record 10 of Set 6 | broken hill
# Processing Record 11 of Set 6 | manching
# Processing Record 12 of Set 6 | otukpo
# Processing Record 13 of Set 6 | waterboro
# Processing Record 14 of Set 6 | leh
# Processing Record 15 of Set 6 | nhulunbuy
# Processing Record 16 of Set 6 | sao filipe
# Processing Record 17 of Set 6 | zaplyusye
# City not found. Skipping...
# Processing Record 18 of Set 6 | hofn
# Processing Record 19 of Set 6 | riyadh
# Processing Record 20 of Set 6 | victoria point
# Processing Record 21 of Set 6 | namatanai
# Processing Record 22 of Set 6 | kazalinsk
# City not found. Skipping...
# Processing Record 23 of Set 6 | antsla
# Processing Record 24 of Set 6 | garowe
# Processing Record 25 of Set 6 | dingle
# Processing Record 26 of Set 6 | glasgow
# Processing Record 27 of Set 6 | noumea
# Processing Record 28 of Set 6 | tucuman
# Processing Record 29 of Set 6 | port macquarie
# Processing Record 30 of Set 6 | aborlan
# Processing Record 31 of Set 6 | manikganj
# Processing Record 32 of Set 6 | ulcinj
# Processing Record 33 of Set 6 | svetlaya
# Processing Record 34 of Set 6 | luau
# Processing Record 35 of Set 6 | toamasina
# Processing Record 36 of Set 6 | katherine
# Processing Record 37 of Set 6 | wanning
# Processing Record 38 of Set 6 | thompson
# Processing Record 39 of Set 6 | curuguaty
# Processing Record 40 of Set 6 | emerald
# Processing Record 41 of Set 6 | baruun-urt
# Processing Record 42 of Set 6 | kharp
# Processing Record 43 of Set 6 | kommunar
# Processing Record 44 of Set 6 | lumby
# Processing Record 45 of Set 6 | pedasi
# Processing Record 46 of Set 6 | nexo
# Processing Record 47 of Set 6 | luderitz
# Processing Record 48 of Set 6 | kruisfontein
# Processing Record 49 of Set 6 | north bend
# Processing Record 50 of Set 6 | nianzishan
# Processing Record 1 of Set 7 | vila franca do campo
# Processing Record 2 of Set 7 | la colorada
# Processing Record 3 of Set 7 | vao
# Processing Record 4 of Set 7 | ilulissat
# Processing Record 5 of Set 7 | aksarka
# Processing Record 6 of Set 7 | port shepstone
# Processing Record 7 of Set 7 | vysotsk
# Processing Record 8 of Set 7 | maraa
# Processing Record 9 of Set 7 | sataua
# City not found. Skipping...
# Processing Record 10 of Set 7 | saint george
# Processing Record 11 of Set 7 | alta floresta
# Processing Record 12 of Set 7 | hun
# Processing Record 13 of Set 7 | isangel
# Processing Record 14 of Set 7 | los llanos de aridane
# Processing Record 15 of Set 7 | hami
# Processing Record 16 of Set 7 | kozhva
# Processing Record 17 of Set 7 | meulaboh
# Processing Record 18 of Set 7 | shingu
# Processing Record 19 of Set 7 | suluq
# Processing Record 20 of Set 7 | souillac
# Processing Record 21 of Set 7 | henties bay
# Processing Record 22 of Set 7 | karkaralinsk
# City not found. Skipping...
# Processing Record 23 of Set 7 | vacha
# Processing Record 24 of Set 7 | mut
# Processing Record 25 of Set 7 | san patricio
# Processing Record 26 of Set 7 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 7 | dudinka
# Processing Record 28 of Set 7 | beyneu
# Processing Record 29 of Set 7 | tommot
# Processing Record 30 of Set 7 | progreso
# Processing Record 31 of Set 7 | yar-sale
# Processing Record 32 of Set 7 | khonuu
# City not found. Skipping...
# Processing Record 33 of Set 7 | ushtobe
# Processing Record 34 of Set 7 | havoysund
# Processing Record 35 of Set 7 | talaya
# Processing Record 36 of Set 7 | chokurdakh
# Processing Record 37 of Set 7 | potgietersrus
# City not found. Skipping...
# Processing Record 38 of Set 7 | devils lake
# Processing Record 39 of Set 7 | havelock
# Processing Record 40 of Set 7 | beringovskiy
# Processing Record 41 of Set 7 | te anau
# Processing Record 42 of Set 7 | port lincoln
# Processing Record 43 of Set 7 | fairlie
# Processing Record 44 of Set 7 | kununurra
# Processing Record 45 of Set 7 | timmins
# Processing Record 46 of Set 7 | mancio lima
# Processing Record 47 of Set 7 | lively
# Processing Record 48 of Set 7 | alyangula
# Processing Record 49 of Set 7 | muisne
# Processing Record 50 of Set 7 | cabo san lucas
# Processing Record 1 of Set 8 | kuloy
# Processing Record 2 of Set 8 | tsagan aman
# Processing Record 3 of Set 8 | upernavik
# Processing Record 4 of Set 8 | bisauli
# Processing Record 5 of Set 8 | aykhal
# Processing Record 6 of Set 8 | kalmunai
# Processing Record 7 of Set 8 | sumbawa
# City not found. Skipping...
# Processing Record 8 of Set 8 | cap malheureux
# Processing Record 9 of Set 8 | pearl
# Processing Record 10 of Set 8 | jining
# Processing Record 11 of Set 8 | novaya zaimka
# Processing Record 12 of Set 8 | bac can
# City not found. Skipping...
# Processing Record 13 of Set 8 | yulara
# Processing Record 14 of Set 8 | sibolga
# Processing Record 15 of Set 8 | vila velha
# Processing Record 16 of Set 8 | kichera
# Processing Record 17 of Set 8 | ibiruba
# Processing Record 18 of Set 8 | buenos aires
# Processing Record 19 of Set 8 | dali
# Processing Record 20 of Set 8 | saldanha
# Processing Record 21 of Set 8 | kamaishi
# Processing Record 22 of Set 8 | ardistan
# City not found. Skipping...
# Processing Record 23 of Set 8 | agva
# City not found. Skipping...
# Processing Record 24 of Set 8 | marawi
# Processing Record 25 of Set 8 | calvinia
# Processing Record 26 of Set 8 | waldoboro
# Processing Record 27 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 8 | amderma
# City not found. Skipping...
# Processing Record 29 of Set 8 | new richmond
# Processing Record 30 of Set 8 | mehamn
# Processing Record 31 of Set 8 | sinnamary
# Processing Record 32 of Set 8 | quatre cocos
# Processing Record 33 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 8 | kannangad
# Processing Record 35 of Set 8 | roseland
# Processing Record 36 of Set 8 | russell
# Processing Record 37 of Set 8 | warmbad
# Processing Record 38 of Set 8 | hrinova
# Processing Record 39 of Set 8 | crib point
# Processing Record 40 of Set 8 | mogadishu
# Processing Record 41 of Set 8 | la asuncion
# Processing Record 42 of Set 8 | colborne
# Processing Record 43 of Set 8 | rundu
# Processing Record 44 of Set 8 | kongolo
# Processing Record 45 of Set 8 | krasnoselkup
# Processing Record 46 of Set 8 | salisbury
# Processing Record 47 of Set 8 | honningsvag
# Processing Record 48 of Set 8 | mrirt
# City not found. Skipping...
# Processing Record 49 of Set 8 | rudnyy
# Processing Record 50 of Set 8 | yishui
# Processing Record 1 of Set 9 | tiznit
# Processing Record 2 of Set 9 | mattawa
# Processing Record 3 of Set 9 | dauphin
# Processing Record 4 of Set 9 | kjollefjord
# Processing Record 5 of Set 9 | mitu
# Processing Record 6 of Set 9 | abeche
# Processing Record 7 of Set 9 | komsomolskiy
# Processing Record 8 of Set 9 | arman
# Processing Record 9 of Set 9 | oranjestad
# Processing Record 10 of Set 9 | yeppoon
# Processing Record 11 of Set 9 | suntar
# Processing Record 12 of Set 9 | balikpapan
# Processing Record 13 of Set 9 | mantes-la-ville
# Processing Record 14 of Set 9 | son la
# Processing Record 15 of Set 9 | mount gambier
# Processing Record 16 of Set 9 | kahramanmaras
# Processing Record 17 of Set 9 | karakendzha
# City not found. Skipping...
# Processing Record 18 of Set 9 | shchigry
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | viligili
# City not found. Skipping...
# Processing Record 21 of Set 9 | vilhena
# Processing Record 22 of Set 9 | ponta delgada
# Processing Record 23 of Set 9 | sur
# Processing Record 24 of Set 9 | grand forks
# Processing Record 25 of Set 9 | khakhea
# Processing Record 26 of Set 9 | vallenar
# Processing Record 27 of Set 9 | robertsport
# Processing Record 28 of Set 9 | mercedes
# Processing Record 29 of Set 9 | fuente de oro
# Processing Record 30 of Set 9 | mosquera
# Processing Record 31 of Set 9 | beroroha
# Processing Record 32 of Set 9 | aflao
# Processing Record 33 of Set 9 | novo aripuana
# Processing Record 34 of Set 9 | labuhan
# Processing Record 35 of Set 9 | kenai
# Processing Record 36 of Set 9 | chitral
# Processing Record 37 of Set 9 | grand centre
# City not found. Skipping...
# Processing Record 38 of Set 9 | tukan
# Processing Record 39 of Set 9 | kuche
# City not found. Skipping...
# Processing Record 40 of Set 9 | vanavara
# Processing Record 41 of Set 9 | lata
# Processing Record 42 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 43 of Set 9 | iracoubo
# Processing Record 44 of Set 9 | rocha
# Processing Record 45 of Set 9 | papara
# Processing Record 46 of Set 9 | chapais
# Processing Record 47 of Set 9 | asfi
# Processing Record 48 of Set 9 | palana
# Processing Record 49 of Set 9 | narsaq
# Processing Record 50 of Set 9 | koslan
# Processing Record 1 of Set 10 | champerico
# Processing Record 2 of Set 10 | bagotville
# Processing Record 3 of Set 10 | la peca
# Processing Record 4 of Set 10 | boma
# Processing Record 5 of Set 10 | kemin
# Processing Record 6 of Set 10 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 10 | batticaloa
# Processing Record 8 of Set 10 | zhezkazgan
# Processing Record 9 of Set 10 | khorramshahr
# Processing Record 10 of Set 10 | purranque
# Processing Record 11 of Set 10 | karpogory
# Processing Record 12 of Set 10 | nyakabindi
# Processing Record 13 of Set 10 | sorland
# Processing Record 14 of Set 10 | kwinana
# Processing Record 15 of Set 10 | ilebo
# Processing Record 16 of Set 10 | svetlogorsk
# Processing Record 17 of Set 10 | susono
# Processing Record 18 of Set 10 | gewane
# Processing Record 19 of Set 10 | natal
# Processing Record 20 of Set 10 | coquimbo
# Processing Record 21 of Set 10 | roma
# Processing Record 22 of Set 10 | kudahuvadhoo
# Processing Record 23 of Set 10 | griffith
# Processing Record 24 of Set 10 | jinchang
# Processing Record 25 of Set 10 | plock
# Processing Record 26 of Set 10 | llaillay
# Processing Record 27 of Set 10 | sabha
# Processing Record 28 of Set 10 | san juan
# Processing Record 29 of Set 10 | normandin
# Processing Record 30 of Set 10 | kifri
# Processing Record 31 of Set 10 | paamiut
# Processing Record 32 of Set 10 | tahe
# Processing Record 33 of Set 10 | matagami
# Processing Record 34 of Set 10 | cidreira
# Processing Record 35 of Set 10 | novyy urengoy
# Processing Record 36 of Set 10 | abalak
# Processing Record 37 of Set 10 | bowen
# Processing Record 38 of Set 10 | moron
# Processing Record 39 of Set 10 | barstow
# Processing Record 40 of Set 10 | maloy
# Processing Record 41 of Set 10 | ondjiva
# Processing Record 42 of Set 10 | ilinsko-podomskoye
# City not found. Skipping...
# Processing Record 43 of Set 10 | tabuk
# Processing Record 44 of Set 10 | palauig
# Processing Record 45 of Set 10 | dulce nombre de culmi
# Processing Record 46 of Set 10 | kushmurun
# Processing Record 47 of Set 10 | irun
# Processing Record 48 of Set 10 | penzance
# Processing Record 49 of Set 10 | maxixe
# Processing Record 50 of Set 10 | labutta
# City not found. Skipping...
# Processing Record 1 of Set 11 | mao
# Processing Record 2 of Set 11 | sal rei
# Processing Record 3 of Set 11 | zharkent
# Processing Record 4 of Set 11 | avera
# Processing Record 5 of Set 11 | najran
# Processing Record 6 of Set 11 | saint anthony
# Processing Record 7 of Set 11 | chambery
# Processing Record 8 of Set 11 | ewa beach
# Processing Record 9 of Set 11 | bafq
# Processing Record 10 of Set 11 | walvis bay
# Processing Record 11 of Set 11 | kloulklubed
# Processing Record 12 of Set 11 | sobolevo
# Processing Record 13 of Set 11 | santa cruz del norte
# Processing Record 14 of Set 11 | pimenta bueno
# Processing Record 15 of Set 11 | geghamasar
# Processing Record 16 of Set 11 | half moon bay
# Processing Record 17 of Set 11 | galesong
# Processing Record 18 of Set 11 | zaltan
# Processing Record 19 of Set 11 | strezhevoy
# Processing Record 20 of Set 11 | nelson bay
# Processing Record 21 of Set 11 | bubaque
# Processing Record 22 of Set 11 | nicoya
# Processing Record 23 of Set 11 | arvika
# Processing Record 24 of Set 11 | smithers
# Processing Record 25 of Set 11 | vila
# Processing Record 26 of Set 11 | lere
# Processing Record 27 of Set 11 | manitouwadge
# Processing Record 28 of Set 11 | along
# Processing Record 29 of Set 11 | izhma
# Processing Record 30 of Set 11 | zhigansk
# Processing Record 31 of Set 11 | sagvag
# Processing Record 32 of Set 11 | diamantino
# Processing Record 33 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 11 | neryungri
# Processing Record 35 of Set 11 | treinta y tres
# Processing Record 36 of Set 11 | saint-francois
# Processing Record 37 of Set 11 | staunton
# Processing Record 38 of Set 11 | puerto penasco
# Processing Record 39 of Set 11 | solovetskiy
# City not found. Skipping...
# Processing Record 40 of Set 11 | aginskoye
# Processing Record 41 of Set 11 | rio gallegos
# Processing Record 42 of Set 11 | delaware
# Processing Record 43 of Set 11 | cuddapah
# Processing Record 44 of Set 11 | wulanhaote
# City not found. Skipping...
# Processing Record 45 of Set 11 | kijang
# Processing Record 46 of Set 11 | walla walla
# Processing Record 47 of Set 11 | tabory
# Processing Record 48 of Set 11 | kerema
# Processing Record 49 of Set 11 | stekolnyy
# City not found. Skipping...
# Processing Record 50 of Set 11 | moussoro
# Processing Record 1 of Set 12 | tanshui
# City not found. Skipping...
# Processing Record 2 of Set 12 | sagaing
# Processing Record 3 of Set 12 | lorengau
# Processing Record 4 of Set 12 | da nang
# Processing Record 5 of Set 12 | matay
# Processing Record 6 of Set 12 | rafai
# Processing Record 7 of Set 12 | bahia blanca
# Processing Record 8 of Set 12 | bayir
# Processing Record 9 of Set 12 | denizli
# Processing Record 10 of Set 12 | san matias
# Processing Record 11 of Set 12 | aloleng
# Processing Record 12 of Set 12 | praia da vitoria
# Processing Record 13 of Set 12 | makung
# City not found. Skipping...
# Processing Record 14 of Set 12 | roald
# Processing Record 15 of Set 12 | alice springs
# Processing Record 16 of Set 12 | makokou
# Processing Record 17 of Set 12 | ostrovnoy
# Processing Record 18 of Set 12 | sambava
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | novobirilyussy
# Processing Record 21 of Set 12 | guerrero negro
# Processing Record 22 of Set 12 | hobyo
# Processing Record 23 of Set 12 | sakaiminato
# Processing Record 24 of Set 12 | iqaluit
# Processing Record 25 of Set 12 | igbo ora
# Processing Record 26 of Set 12 | jinka
# Processing Record 27 of Set 12 | abatskoye
# Processing Record 28 of Set 12 | mandalgovi
# Processing Record 29 of Set 12 | verkhnevilyuysk
# Processing Record 30 of Set 12 | hereford
# Processing Record 31 of Set 12 | la reforma
# Processing Record 32 of Set 12 | san quintin
# Processing Record 33 of Set 12 | neuquen
# Processing Record 34 of Set 12 | san policarpo
# Processing Record 35 of Set 12 | menongue
# Processing Record 36 of Set 12 | mezhdurechensk
# Processing Record 37 of Set 12 | capim grosso
# Processing Record 38 of Set 12 | bundaberg
# Processing Record 39 of Set 12 | wewak
# Processing Record 40 of Set 12 | rudnaya pristan
# Processing Record 41 of Set 12 | mananara
# Processing Record 42 of Set 12 | mitchell
# Processing Record 43 of Set 12 | marietta
# Processing Record 44 of Set 12 | hunza
# City not found. Skipping...
# Processing Record 45 of Set 12 | hovd
# Processing Record 46 of Set 12 | puerto montt
# Processing Record 47 of Set 12 | portland
# Processing Record 48 of Set 12 | meylan
# Processing Record 49 of Set 12 | tutoia
# Processing Record 50 of Set 12 | morant bay
# Processing Record 1 of Set 13 | hermiston
# Processing Record 2 of Set 13 | ucluelet
# Processing Record 3 of Set 13 | gandorhun
# Processing Record 4 of Set 13 | boralday
# Processing Record 5 of Set 13 | uvalde
# Processing Record 6 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 7 of Set 13 | fairbanks
# Processing Record 8 of Set 13 | solyanka
# Processing Record 9 of Set 13 | geraldton
# Processing Record 10 of Set 13 | yeniseysk
# Processing Record 11 of Set 13 | nishiwaki
# Processing Record 12 of Set 13 | chaa-khol
# City not found. Skipping...
# Processing Record 13 of Set 13 | padang
# Processing Record 14 of Set 13 | uyuni
# Processing Record 15 of Set 13 | samalaeulu
# City not found. Skipping...
# Processing Record 16 of Set 13 | bontang
# Processing Record 17 of Set 13 | talnakh
# Processing Record 18 of Set 13 | falealupo
# City not found. Skipping...
# Processing Record 19 of Set 13 | tirumullaivasal
# Processing Record 20 of Set 13 | atamanovka
# Processing Record 21 of Set 13 | puerto boyaca
# Processing Record 22 of Set 13 | bellefontaine
# Processing Record 23 of Set 13 | uyemskiy
# Processing Record 24 of Set 13 | anchorage
# Processing Record 25 of Set 13 | carupano
# Processing Record 26 of Set 13 | lethem
# Processing Record 27 of Set 13 | albertville
# Processing Record 28 of Set 13 | vestmannaeyjar
# Processing Record 29 of Set 13 | gandu
# Processing Record 30 of Set 13 | pyrzyce
# Processing Record 31 of Set 13 | pascagoula
# Processing Record 32 of Set 13 | fort nelson
# Processing Record 33 of Set 13 | cooma
# Processing Record 34 of Set 13 | la sarre
# Processing Record 35 of Set 13 | kamenskoye
# City not found. Skipping...
# Processing Record 36 of Set 13 | hirado
# Processing Record 37 of Set 13 | bambanglipuro
# Processing Record 38 of Set 13 | severnyy
# Processing Record 39 of Set 13 | tarudant
# City not found. Skipping...
# Processing Record 40 of Set 13 | bud
# Processing Record 41 of Set 13 | mashhad
# Processing Record 42 of Set 13 | peniche
# Processing Record 43 of Set 13 | ardakan
# Processing Record 44 of Set 13 | owensboro
# Processing Record 45 of Set 13 | les cayes
# Processing Record 46 of Set 13 | lahaina
# Processing Record 47 of Set 13 | bac
# Processing Record 48 of Set 13 | talah
# City not found. Skipping...
# Processing Record 49 of Set 13 | pringsewu
# Processing Record 50 of Set 13 | burtunay
# Processing Record 1 of Set 14 | farmington
# Processing Record 2 of Set 14 | gidam
# Processing Record 3 of Set 14 | sola
# Processing Record 4 of Set 14 | panzhihua
# Processing Record 5 of Set 14 | zamora
# Processing Record 6 of Set 14 | vanimo
# Processing Record 7 of Set 14 | semey
# Processing Record 8 of Set 14 | bonoua
# Processing Record 9 of Set 14 | raahe
# Processing Record 10 of Set 14 | lashio
# Processing Record 11 of Set 14 | belaya gora
# Processing Record 12 of Set 14 | raudeberg
# Processing Record 13 of Set 14 | qasigiannguit
# Processing Record 14 of Set 14 | marsh harbour
# Processing Record 15 of Set 14 | ola
# Processing Record 16 of Set 14 | lubango
# Processing Record 17 of Set 14 | santiago
# Processing Record 18 of Set 14 | miles city
# Processing Record 19 of Set 14 | bereda
# Processing Record 20 of Set 14 | grand-bourg
# Processing Record 21 of Set 14 | castanos
# Processing Record 22 of Set 14 | luang prabang
# Processing Record 23 of Set 14 | petropavlovsk-kamchatskiy
# Processing Record 24 of Set 14 | satitoa
# City not found. Skipping...
# Processing Record 25 of Set 14 | kirakira
# Processing Record 26 of Set 14 | mackenzie
# Processing Record 27 of Set 14 | benghazi
# Processing Record 28 of Set 14 | toliary
# City not found. Skipping...
# Processing Record 29 of Set 14 | krasnogvardeyskoye
# Processing Record 30 of Set 14 | las palmas
# Processing Record 31 of Set 14 | ivanovka
# Processing Record 32 of Set 14 | niquero
# Processing Record 33 of Set 14 | hay river
# Processing Record 34 of Set 14 | honiara
# Processing Record 35 of Set 14 | rapid valley
# Processing Record 36 of Set 14 | lima
# Processing Record 37 of Set 14 | baykit
# Processing Record 38 of Set 14 | mozhga
# Processing Record 39 of Set 14 | jalu
# Processing Record 40 of Set 14 | klyuchi
# Processing Record 41 of Set 14 | edgewater
# Processing Record 42 of Set 14 | caraballeda
# Processing Record 43 of Set 14 | sorvag
# City not found. Skipping...
# Processing Record 44 of Set 14 | wahran
# City not found. Skipping...
# Processing Record 45 of Set 14 | ures
# Processing Record 46 of Set 14 | jacareacanga
# Processing Record 47 of Set 14 | borogontsy
# Processing Record 48 of Set 14 | muros
# Processing Record 49 of Set 14 | ekhabi
# Processing Record 50 of Set 14 | cheuskiny
# City not found. Skipping...
# Processing Record 1 of Set 15 | hinche
# Processing Record 2 of Set 15 | luganville
# Processing Record 3 of Set 15 | verkhoyansk
# Processing Record 4 of Set 15 | kerman
# Processing Record 5 of Set 15 | shenjiamen
# Processing Record 6 of Set 15 | elizabethton
# Processing Record 7 of Set 15 | gravdal
# Processing Record 8 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 15 | camacha
# Processing Record 10 of Set 15 | kulhudhuffushi
# Processing Record 11 of Set 15 | mount isa
# Processing Record 12 of Set 15 | mayo
# Processing Record 13 of Set 15 | barcelos
# Processing Record 14 of Set 15 | quartucciu
# Processing Record 15 of Set 15 | beterou
# Processing Record 16 of Set 15 | baboua
# City not found. Skipping...
# Processing Record 17 of Set 15 | buritis
# Processing Record 18 of Set 15 | tiarei
# Processing Record 19 of Set 15 | korla
# Processing Record 20 of Set 15 | arkadak
# Processing Record 21 of Set 15 | kashan
# Processing Record 22 of Set 15 | flin flon
# Processing Record 23 of Set 15 | port blair
# Processing Record 24 of Set 15 | saint-georges
# Processing Record 25 of Set 15 | sangar
# Processing Record 26 of Set 15 | haibowan
# City not found. Skipping...
# Processing Record 27 of Set 15 | hongjiang
# Processing Record 28 of Set 15 | nalut
# Processing Record 29 of Set 15 | padrauna
# Processing Record 30 of Set 15 | kant
# Processing Record 31 of Set 15 | sokoni
# Processing Record 32 of Set 15 | batemans bay
# Processing Record 33 of Set 15 | bundi
# Processing Record 34 of Set 15 | tortoli
# Processing Record 35 of Set 15 | ivdel
# Processing Record 36 of Set 15 | lolua
# City not found. Skipping...
# Processing Record 37 of Set 15 | kavaratti
# Processing Record 38 of Set 15 | seara
# Processing Record 39 of Set 15 | pacifica
# Processing Record 40 of Set 15 | tonstad
# Processing Record 41 of Set 15 | tautira
# Processing Record 42 of Set 15 | mtwara
# Processing Record 43 of Set 15 | lucapa
# Processing Record 44 of Set 15 | mutoko
# Processing Record 45 of Set 15 | pangai
# Processing Record 46 of Set 15 | digha
# Processing Record 47 of Set 15 | xingyi
# Processing Record 48 of Set 15 | foki
# Processing Record 49 of Set 15 | goderich
# Processing Record 50 of Set 15 | prince rupert
# Processing Record 1 of Set 16 | pakxan
# Processing Record 2 of Set 16 | nyimba
# Processing Record 3 of Set 16 | lasa
# Processing Record 4 of Set 16 | ferme-neuve
# Processing Record 5 of Set 16 | binabalian
# Processing Record 6 of Set 16 | talavera de la reina
# Processing Record 7 of Set 16 | turbat
# Processing Record 8 of Set 16 | elverum
# Processing Record 9 of Set 16 | nishihara
# Processing Record 10 of Set 16 | belozerskoye
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
#7 Add the data to a new DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Nanortalik  60.1432  -45.2371     35.17        82          88
# 1  Arraial Do Cabo -22.9661  -42.0278     68.92        89         100
# 2          College  64.8569 -147.8028     19.72        90          90
# 3     Norman Wells  65.2820 -126.8329     24.84        93          90
# 4   Ribeira Grande  38.5167  -28.7000     69.53        90          81
# 5         Waingapu  -9.6567  120.2641     87.67        62           3
# 6           Kodiak  57.7900 -152.4072     44.28        81          90
# 7           Bonthe   7.5264  -12.5050     76.77        87         100
# 8           Hobart -42.8794  147.3294     55.26        62          75
# 9        Tecoanapa  16.5167  -98.7500     80.47        82           6
#
#    Wind Speed Country Weather Condition
# 0        8.19      GL   overcast clouds
# 1       17.52      BR   overcast clouds
# 2        4.61      US   overcast clouds
# 3        2.30      CA        light snow
# 4       13.73      PT     broken clouds
# 5        8.12      ID         clear sky
# 6       17.27      US     moderate rain
# 7        7.16      SL     moderate rain
# 8        1.01      AU     broken clouds
# 9        6.71      MX         clear sky

# %%
#8 Export City data to a csv file
city_data_df.to_csv("WeatherPy_Database.csv")
